# %% [markdown]
# <a href="https://colab.research.google.com/github/agnkow/ak_ner/blob/master/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Przykład zastosowania biblioteki ak_ner

# %%
# Instalacja biblioteki, pobranie modelu spacy
# !pip3 install -U git+https://github.com/agnkow/ak_ner.git@master
# !spacy download pl_core_news_sm

# %%
# Import biblioteki
import ak_ner as nn

# %% [markdown]
# Wczytanie przykładowych danych

# %%
# format danych wejściwych: pd.DataFrame
data_cire = nn.read_example()
data_cire.head(2)
# Out:
#    index         text_date                                                url  \
# 0      0  2021-11-24 10:00  https://rynek-gazu.cire.pl/artykuly/serwis-inf...
# 1      1  2021-11-23 21:00  https://rynek-gazu.cire.pl/artykuly/serwis-inf...
#
#                                                 text
# 0  Górnośląsko-Zagłębiowska Metropolia ma ofertę ...
# 1  Nord Stream 2 wspiera fundacja klimatyczna z M...

# %%
# format danych wejściwych: string
data_cire_str = nn.read_example('str')
data_cire_str[:600]
# Out:
# 'Komisja Europejska poinformowała w środę, że zatwierdziła, zgodnie z unijnymi zasadami pomocy publicznej, plan udzielenia przez Polskę ok. 22 mln euro (100 mln zł) pomocy restrukturyzacyjnej spółce Rafako. PGNiG zawarło umowę kredytową z Bankiem Gospodarstwa Krajowego do kwoty 4,8 mld zł na okres 24 miesięcy od daty podpisania umowy kredytowej. Przy automatycznym pomiarze i przesyle danych o zużyciu mediów przedsiębiorca wie, ile gazu zużywa na ogrzewanie pomieszczeń, ile na podgrzanie wody, a ile na procesy technologiczne. To pozwala mu reagować i zmniejszać zużycie.  Analogiczne oszczędności'

# %% [markdown]
# Rozpoznanie jednostek nazewniczych dla przykładowych danch z portalu CIRE

# %%
# format danych wejściwych: pd.DataFrame
cire_ner_df = nn.extract_ner_spacy(data_cire, model='pl_core_news_sm')
cire_ner_df.tail(5)
# Out:
#      id_doc    identified         lemma     entity
# 130       4      Mołdawii      mołdawii  placeName
# 131       4  Wadim Czeban  Wadim Czeban   persName
# 132       4      Gazpromu       Gazprom    orgName
# 133       4        Czeban        Czeban   persName
# 134       4      listopad      listopad       date

# %%
# format danych wejściwych: string
cire_ner = nn.extract_ner_spacy(data_cire_str, model='pl_core_news_sm')
cire_ner.head(3)
# Out:
#            identified               lemma     entity
# 0  Komisja Europejska  komisja europejski    orgName
# 1              Polskę              Polska  placeName
# 2              Rafako              rafako    orgName
